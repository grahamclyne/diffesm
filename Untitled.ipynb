# %%
import xarray as xr

# %%
target_ds = xr.open_dataset('/lustre/fsn1/projects/rech/mlr/udy16au/dcpp_dataset/1960_1.nc')

# %%
target_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 120, lat: 143, lon: 144, plev: 4)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time         (time) datetime64[ns] 1961-01-16T12:00:00 ... 1970-12-16T12:...
#   * plev         (plev) float32 8.5e+04 7e+04 5e+04 2.5e+04
#     height       float64 ...
# Data variables: (12/26)
#     clt          (time, lat, lon) float32 ...
#     hurs         (time, lat, lon) float32 ...
#     huss         (time, lat, lon) float32 ...
#     pr           (time, lat, lon) float32 ...
#     ps           (time, lat, lon) float32 ...
#     psl          (time, lat, lon) float32 ...
#     ...           ...
#     thetaot2000  (time, lat, lon) float32 ...
#     thetaot300   (time, lat, lon) float32 ...
#     thetaot700   (time, lat, lon) float32 ...
#     t20d         (time, lat, lon) float32 ...
# ...

# %%
pred = xr.open_dataset('/lustre/fsn1/projects/rech/mlr/udy16au/generated_data/IPSL/dcpp/val_tas_pr_1961-1971.nc')

# %%
pred.tas.time
# Out:
# <xarray.DataArray 'time' (time: 120)>
# array(['1962-01-16T12:00:00.000000000', '1962-02-15T00:00:00.000000000',
#        '1962-03-16T12:00:00.000000000', '1962-04-16T00:00:00.000000000',
#        '1962-05-16T12:00:00.000000000', '1962-06-16T00:00:00.000000000',
#        '1962-07-16T12:00:00.000000000', '1962-08-16T12:00:00.000000000',
#        '1962-09-16T00:00:00.000000000', '1962-10-16T12:00:00.000000000',
#        '1962-11-16T00:00:00.000000000', '1962-12-16T12:00:00.000000000',
#        '1963-01-16T12:00:00.000000000', '1963-02-15T00:00:00.000000000',
#        '1963-03-16T12:00:00.000000000', '1963-04-16T00:00:00.000000000',
#        '1963-05-16T12:00:00.000000000', '1963-06-16T00:00:00.000000000',
#        '1963-07-16T12:00:00.000000000', '1963-08-16T12:00:00.000000000',
#        '1963-09-16T00:00:00.000000000', '1963-10-16T12:00:00.000000000',
#        '1963-11-16T00:00:00.000000000', '1963-12-16T12:00:00.000000000',
# ...

# %%
import torch

# %%
ac_pred = torch.load('/lustre/fswork/projects/rech/mlr/udy16au/ArchesClimate/ArchesClimate/generated_data/forecast_added_input_state_0_4000_10_1_118_1_val_0/rollout_0_surface.pt', map_location=torch.device('cpu'))

# %%
import matplotlib.pyplot as plt

# %%
target_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 120, lat: 143, lon: 144, plev: 4)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time         (time) datetime64[ns] 1961-01-16T12:00:00 ... 1970-12-16T12:...
#   * plev         (plev) float32 8.5e+04 7e+04 5e+04 2.5e+04
#     height       float64 ...
# Data variables: (12/26)
#     clt          (time, lat, lon) float32 ...
#     hurs         (time, lat, lon) float32 ...
#     huss         (time, lat, lon) float32 ...
#     pr           (time, lat, lon) float32 ...
#     ps           (time, lat, lon) float32 ...
#     psl          (time, lat, lon) float32 ...
#     ...           ...
#     thetaot2000  (time, lat, lon) float32 ...
#     thetaot300   (time, lat, lon) float32 ...
#     thetaot700   (time, lat, lon) float32 ...
#     t20d         (time, lat, lon) float32 ...
# ...

# %%
plt.plot((pred['tas']+273).mean(dim=('lat','lon')).values)
plt.plot(target_ds['tas'].mean(dim=('lat','lon')).values)
plt.plot(ac_pred[0,:,0,0].nanmean(axis=(-1,-2)))
